# %% [markdown]
# <a href="https://colab.research.google.com/github/avsdc/PortfolioProjects/blob/master/Police_Deaths_In_USA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install --upgrade plotly

# %% [markdown]
# # **Import  Statements**

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

import plotly.graph_objects as go

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
df = pd.read_csv("police_deaths_538.csv")
df
# Out:
#                            person  \
# 0         Constable Darius Quimby
# 1      Sheriff Cornelius Hogeboom
# 2      Deputy Sheriff Isaac Smith
# 3          Marshal Robert Forsyth
# 4          Sheriff Robert Maxwell
# ...                           ...
# 22795                    K9 Bruno
# 22796                    K9 Lazer
# 22797                    K9 Tyson
# 22798                    K9 Credo
# 22799                   K9 Roscoe
#
#                                                     dept  \
# 0                   Albany County Constable's Office, NY
# 1                   Columbia County Sheriff's Office, NY
# 2            Westchester County Sheriff's Department, NY
# 3      United States Department of Justice - United S...
# 4                 Greenville County Sheriff's Office, SC
# ...                                                  ...
# 22795                     Amarillo Police Department, TX
# 22796  United States Department of Homeland Security ...
# 22797               Fountain County Sheriff's Office, IN
# 22798                   Long Beach Police Department, CA
# 22799                       Emmett Police Department, ID
#
#                                    eow                                 cause  \
# 0         EOW: Monday, January 3, 1791               Cause of Death: Gunfire
# 1      EOW: Saturday, October 22, 1791               Cause of Death: Gunfire
# 2          EOW: Thursday, May 17, 1792               Cause of Death: Gunfire
# 3      EOW: Saturday, January 11, 1794               Cause of Death: Gunfire
# 4       EOW: Sunday, November 12, 1797               Cause of Death: Gunfire
# ...                                ...                                   ...
# 22795       EOW: Sunday, June 12, 2016            Cause of Death: Accidental
# 22796       EOW: Monday, June 20, 2016       Cause of Death: Heat exhaustion
# 22797       EOW: Monday, June 27, 2016       Cause of Death: Heat exhaustion
# 22798      EOW: Tuesday, June 28, 2016  Cause of Death: Gunfire (Accidental)
# 22799        EOW: Friday, July 1, 2016   Cause of Death: Automobile accident
#
#                 cause_short        date  year  canine  \
# 0                   Gunfire  1791-01-03  1791   False
# 1                   Gunfire  1791-10-22  1791   False
# 2                   Gunfire  1792-05-17  1792   False
# 3                   Gunfire  1794-01-11  1794   False
# 4                   Gunfire  1797-11-12  1797   False
# ...                     ...         ...   ...     ...
# 22795            Accidental  2016-06-12  2016    True
# 22796       Heat exhaustion  2016-06-20  2016    True
# 22797       Heat exhaustion  2016-06-27  2016    True
# 22798  Gunfire (Accidental)  2016-06-28  2016    True
# 22799   Automobile accident  2016-07-01  2016    True
#
#                                                dept_name state
# 0                       Albany County Constable's Office    NY
# 1                       Columbia County Sheriff's Office    NY
# 2                Westchester County Sheriff's Department    NY
# 3      United States Department of Justice - United S...    US
# 4                     Greenville County Sheriff's Office    SC
# ...                                                  ...   ...
# 22795                         Amarillo Police Department    TX
# 22796  United States Department of Homeland Security ...    US
# 22797                   Fountain County Sheriff's Office    IN
# 22798                       Long Beach Police Department    CA
# 22799                           Emmett Police Department    ID
#
# [22800 rows x 10 columns]

# %% [markdown]
# # **Data Information And Cleaning**

# %%
df.shape
# Out:
# (22800, 10)

# %%
list[df.columns]
# Out:
# list[Index(['person', 'dept', 'eow', 'cause', 'cause_short', 'date', 'year',
#        'canine', 'dept_name', 'state'],
#       dtype='object')]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
print(f'Any duplicates? {df.duplicated().values.any()}')
# Out:
# Any duplicates? False

# %%
nan_df = df.isna()
print(nan_df)
# Out:
#        person   dept    eow  cause  cause_short   date   year  canine  \
# 0       False  False  False  False        False  False  False   False
# 1       False  False  False  False        False  False  False   False
# 2       False  False  False  False        False  False  False   False
# 3       False  False  False  False        False  False  False   False
# 4       False  False  False  False        False  False  False   False
# ...       ...    ...    ...    ...          ...    ...    ...     ...
# 22795   False  False  False  False        False  False  False   False
# 22796   False  False  False  False        False  False  False   False
# 22797   False  False  False  False        False  False  False   False
# 22798   False  False  False  False        False  False  False   False
# 22799   False  False  False  False        False  False  False   False
#
#        dept_name  state
# 0          False  False
# 1          False  False
# 2          False  False
# 3          False  False
# 4          False  False
# ...          ...    ...
# 22795      False  False
# 22796      False  False
# 22797      False  False
# 22798      False  False
# 22799      False  False
#
# [22800 rows x 10 columns]

# %%
print(df.columns.tolist())
# Out:
# ['person', 'dept', 'eow', 'cause', 'cause_short', 'date', 'year', 'canine', 'dept_name', 'state']

# %%
df.columns = df.columns.str.strip()
df
# Out:
#                            person  \
# 0         Constable Darius Quimby
# 1      Sheriff Cornelius Hogeboom
# 2      Deputy Sheriff Isaac Smith
# 3          Marshal Robert Forsyth
# 4          Sheriff Robert Maxwell
# ...                           ...
# 22795                    K9 Bruno
# 22796                    K9 Lazer
# 22797                    K9 Tyson
# 22798                    K9 Credo
# 22799                   K9 Roscoe
#
#                                                     dept  \
# 0                   Albany County Constable's Office, NY
# 1                   Columbia County Sheriff's Office, NY
# 2            Westchester County Sheriff's Department, NY
# 3      United States Department of Justice - United S...
# 4                 Greenville County Sheriff's Office, SC
# ...                                                  ...
# 22795                     Amarillo Police Department, TX
# 22796  United States Department of Homeland Security ...
# 22797               Fountain County Sheriff's Office, IN
# 22798                   Long Beach Police Department, CA
# 22799                       Emmett Police Department, ID
#
#                                    eow                                 cause  \
# 0         EOW: Monday, January 3, 1791               Cause of Death: Gunfire
# 1      EOW: Saturday, October 22, 1791               Cause of Death: Gunfire
# 2          EOW: Thursday, May 17, 1792               Cause of Death: Gunfire
# 3      EOW: Saturday, January 11, 1794               Cause of Death: Gunfire
# 4       EOW: Sunday, November 12, 1797               Cause of Death: Gunfire
# ...                                ...                                   ...
# 22795       EOW: Sunday, June 12, 2016            Cause of Death: Accidental
# 22796       EOW: Monday, June 20, 2016       Cause of Death: Heat exhaustion
# 22797       EOW: Monday, June 27, 2016       Cause of Death: Heat exhaustion
# 22798      EOW: Tuesday, June 28, 2016  Cause of Death: Gunfire (Accidental)
# 22799        EOW: Friday, July 1, 2016   Cause of Death: Automobile accident
#
#                 cause_short        date  year  canine  \
# 0                   Gunfire  1791-01-03  1791   False
# 1                   Gunfire  1791-10-22  1791   False
# 2                   Gunfire  1792-05-17  1792   False
# 3                   Gunfire  1794-01-11  1794   False
# 4                   Gunfire  1797-11-12  1797   False
# ...                     ...         ...   ...     ...
# 22795            Accidental  2016-06-12  2016    True
# 22796       Heat exhaustion  2016-06-20  2016    True
# 22797       Heat exhaustion  2016-06-27  2016    True
# 22798  Gunfire (Accidental)  2016-06-28  2016    True
# 22799   Automobile accident  2016-07-01  2016    True
#
#                                                dept_name state
# 0                       Albany County Constable's Office    NY
# 1                       Columbia County Sheriff's Office    NY
# 2                Westchester County Sheriff's Department    NY
# 3      United States Department of Justice - United S...    US
# 4                     Greenville County Sheriff's Office    SC
# ...                                                  ...   ...
# 22795                         Amarillo Police Department    TX
# 22796  United States Department of Homeland Security ...    US
# 22797                   Fountain County Sheriff's Office    IN
# 22798                       Long Beach Police Department    CA
# 22799                           Emmett Police Department    ID
#
# [22800 rows x 10 columns]

# %%
df.dtypes
# Out:
# person         object
# dept           object
# eow            object
# cause          object
# cause_short    object
# date           object
# year            int64
# canine           bool
# dept_name      object
# state          object
# dtype: object

# %%
print(f'Any NaN values among the data? {df.isna().values.any()}')
# Out:
# Any NaN values among the data? False

# %%
df.isna().sum()
# Out:
# person         0
# dept           0
# eow            0
# cause          0
# cause_short    0
# date           0
# year           0
# canine         0
# dept_name      0
# state          0
# dtype: int64

# %%
df
# Out:
#                            person  \
# 0         Constable Darius Quimby
# 1      Sheriff Cornelius Hogeboom
# 2      Deputy Sheriff Isaac Smith
# 3          Marshal Robert Forsyth
# 4          Sheriff Robert Maxwell
# ...                           ...
# 22795                    K9 Bruno
# 22796                    K9 Lazer
# 22797                    K9 Tyson
# 22798                    K9 Credo
# 22799                   K9 Roscoe
#
#                                                     dept  \
# 0                   Albany County Constable's Office, NY
# 1                   Columbia County Sheriff's Office, NY
# 2            Westchester County Sheriff's Department, NY
# 3      United States Department of Justice - United S...
# 4                 Greenville County Sheriff's Office, SC
# ...                                                  ...
# 22795                     Amarillo Police Department, TX
# 22796  United States Department of Homeland Security ...
# 22797               Fountain County Sheriff's Office, IN
# 22798                   Long Beach Police Department, CA
# 22799                       Emmett Police Department, ID
#
#                                    eow                                 cause  \
# 0         EOW: Monday, January 3, 1791               Cause of Death: Gunfire
# 1      EOW: Saturday, October 22, 1791               Cause of Death: Gunfire
# 2          EOW: Thursday, May 17, 1792               Cause of Death: Gunfire
# 3      EOW: Saturday, January 11, 1794               Cause of Death: Gunfire
# 4       EOW: Sunday, November 12, 1797               Cause of Death: Gunfire
# ...                                ...                                   ...
# 22795       EOW: Sunday, June 12, 2016            Cause of Death: Accidental
# 22796       EOW: Monday, June 20, 2016       Cause of Death: Heat exhaustion
# 22797       EOW: Monday, June 27, 2016       Cause of Death: Heat exhaustion
# 22798      EOW: Tuesday, June 28, 2016  Cause of Death: Gunfire (Accidental)
# 22799        EOW: Friday, July 1, 2016   Cause of Death: Automobile accident
#
#                 cause_short        date  year  canine  \
# 0                   Gunfire  1791-01-03  1791   False
# 1                   Gunfire  1791-10-22  1791   False
# 2                   Gunfire  1792-05-17  1792   False
# 3                   Gunfire  1794-01-11  1794   False
# 4                   Gunfire  1797-11-12  1797   False
# ...                     ...         ...   ...     ...
# 22795            Accidental  2016-06-12  2016    True
# 22796       Heat exhaustion  2016-06-20  2016    True
# 22797       Heat exhaustion  2016-06-27  2016    True
# 22798  Gunfire (Accidental)  2016-06-28  2016    True
# 22799   Automobile accident  2016-07-01  2016    True
#
#                                                dept_name state
# 0                       Albany County Constable's Office    NY
# 1                       Columbia County Sheriff's Office    NY
# 2                Westchester County Sheriff's Department    NY
# 3      United States Department of Justice - United S...    US
# 4                     Greenville County Sheriff's Office    SC
# ...                                                  ...   ...
# 22795                         Amarillo Police Department    TX
# 22796  United States Department of Homeland Security ...    US
# 22797                   Fountain County Sheriff's Office    IN
# 22798                       Long Beach Police Department    CA
# 22799                           Emmett Police Department    ID
#
# [22800 rows x 10 columns]

# %%
# Drop rows where year is less than 1974
df = df[df['year'] >= 1974]
df
# Out:
#                                  person  \
# 14922    Chief of Police Amedeo A. Lisi
# 14923   Deputy Sheriff Donald Dean Love
# 14924     Deputy Sheriff Joe Smith, Jr.
# 14925        Patrolman William F. Brown
# 14926  Lieutenant James Raymond Merrill
# ...                                 ...
# 22795                          K9 Bruno
# 22796                          K9 Lazer
# 22797                          K9 Tyson
# 22798                          K9 Credo
# 22799                         K9 Roscoe
#
#                                                     dept  \
# 14922                        Lyons Police Department, NY
# 14923           Macoupin County Sheriff's Department, IL
# 14924             Cumberland County Sheriff's Office, NC
# 14925                         Lima Police Department, OH
# 14926                  Cache County Sheriff's Office, UT
# ...                                                  ...
# 22795                     Amarillo Police Department, TX
# 22796  United States Department of Homeland Security ...
# 22797               Fountain County Sheriff's Office, IN
# 22798                   Long Beach Police Department, CA
# 22799                       Emmett Police Department, ID
#
#                                    eow                                 cause  \
# 14922  EOW: Wednesday, January 2, 1974   Cause of Death: Automobile accident
# 14923     EOW: Friday, January 4, 1974          Cause of Death: Heart attack
# 14924   EOW: Saturday, January 5, 1974               Cause of Death: Gunfire
# 14925   EOW: Saturday, January 5, 1974               Cause of Death: Gunfire
# 14926   EOW: Saturday, January 5, 1974                  Cause of Death: Fall
# ...                                ...                                   ...
# 22795       EOW: Sunday, June 12, 2016            Cause of Death: Accidental
# 22796       EOW: Monday, June 20, 2016       Cause of Death: Heat exhaustion
# 22797       EOW: Monday, June 27, 2016       Cause of Death: Heat exhaustion
# 22798      EOW: Tuesday, June 28, 2016  Cause of Death: Gunfire (Accidental)
# 22799        EOW: Friday, July 1, 2016   Cause of Death: Automobile accident
#
#                 cause_short        date  year  canine  \
# 14922   Automobile accident  1974-01-02  1974   False
# 14923          Heart attack  1974-01-04  1974   False
# 14924               Gunfire  1974-01-05  1974   False
# 14925               Gunfire  1974-01-05  1974   False
# 14926                  Fall  1974-01-05  1974   False
# ...                     ...         ...   ...     ...
# 22795            Accidental  2016-06-12  2016    True
# 22796       Heat exhaustion  2016-06-20  2016    True
# 22797       Heat exhaustion  2016-06-27  2016    True
# 22798  Gunfire (Accidental)  2016-06-28  2016    True
# 22799   Automobile accident  2016-07-01  2016    True
#
#                                                dept_name state
# 14922                            Lyons Police Department    NY
# 14923               Macoupin County Sheriff's Department    IL
# 14924                 Cumberland County Sheriff's Office    NC
# 14925                             Lima Police Department    OH
# 14926                      Cache County Sheriff's Office    UT
# ...                                                  ...   ...
# 22795                         Amarillo Police Department    TX
# 22796  United States Department of Homeland Security ...    US
# 22797                   Fountain County Sheriff's Office    IN
# 22798                       Long Beach Police Department    CA
# 22799                           Emmett Police Department    ID
#
# [7878 rows x 10 columns]

# %%
df.shape
# Out:
# (7878, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7878 entries, 14922 to 22799
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   person       7878 non-null   object
#  1   dept         7878 non-null   object
#  2   eow          7878 non-null   object
#  3   cause        7878 non-null   object
#  4   cause_short  7878 non-null   object
#  5   date         7878 non-null   object
#  6   year         7878 non-null   int64
#  7   canine       7878 non-null   bool
#  8   dept_name    7878 non-null   object
#  9   state        7878 non-null   object
# dtypes: bool(1), int64(1), object(8)
# memory usage: 881.2+ KB

# %% [markdown]
# # **Deaths By State**

# %%
df_states = df['state'].value_counts()

# %% [markdown]
# ## **Number Of Deaths Per State**

# %%
v_bar = px.bar(
            x = df_states.index,
            y = df_states.values,
            color = df_states.values,
            color_continuous_scale='Aggrnyl',
            title='Number of Deaths per State')

v_bar.update_layout(xaxis_title='States',
                        coloraxis_showscale=False,
                        yaxis_title='Number of Deaths')
v_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9abd097d-1799-4b3e-b639-df02a3e768ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9abd097d-1799-4b3e-b639-df02a3e768ad")) {                    Plotly.newPlot(                        "9abd097d-1799-4b3e-b639-df02a3e768ad",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[656,641,540,440,427,294,249,243,233,227,213,212,205,202,181,175,170,163,154,153,152,148,146,123,120,119,109,101,99,98,75,71,66,66,50,48,46,45,43,37,36,36,30,28,25,24,24,19,19,15,12,12,12,10,10,10,10,3,3],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[" CA"," TX"," NY"," FL"," US"," GA"," IL"," PR"," PA"," OH"," NC"," LA"," AL"," TN"," MI"," VA"," SC"," MO"," NJ"," IN"," AZ"," MS"," MD"," AR"," KY"," OK"," MA"," WA"," CO"," WI"," MN"," NM"," KS"," OR"," UT"," WV"," IA"," NV"," CT"," TR"," AK"," DC"," MT"," HI"," NE"," ME"," ID"," NH"," WY"," SD"," RR"," VT"," DE"," VI"," ND"," GU"," RI"," AS"," MP"],"xaxis":"x","y":[656,641,540,440,427,294,249,243,233,227,213,212,205,202,181,175,170,163,154,153,152,148,146,123,120,119,109,101,99,98,75,71,66,66,50,48,46,45,43,37,36,36,30,28,25,24,24,19,19,15,12,12,12,10,10,10,10,3,3],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555 ...

# %% [markdown]
# # **Number Of Deaths Due To Various Causes**

# %%
df_cause_short = df['cause_short'].value_counts()
df
# Out:
#                                  person  \
# 14922    Chief of Police Amedeo A. Lisi
# 14923   Deputy Sheriff Donald Dean Love
# 14924     Deputy Sheriff Joe Smith, Jr.
# 14925        Patrolman William F. Brown
# 14926  Lieutenant James Raymond Merrill
# ...                                 ...
# 22795                          K9 Bruno
# 22796                          K9 Lazer
# 22797                          K9 Tyson
# 22798                          K9 Credo
# 22799                         K9 Roscoe
#
#                                                     dept  \
# 14922                        Lyons Police Department, NY
# 14923           Macoupin County Sheriff's Department, IL
# 14924             Cumberland County Sheriff's Office, NC
# 14925                         Lima Police Department, OH
# 14926                  Cache County Sheriff's Office, UT
# ...                                                  ...
# 22795                     Amarillo Police Department, TX
# 22796  United States Department of Homeland Security ...
# 22797               Fountain County Sheriff's Office, IN
# 22798                   Long Beach Police Department, CA
# 22799                       Emmett Police Department, ID
#
#                                    eow                                 cause  \
# 14922  EOW: Wednesday, January 2, 1974   Cause of Death: Automobile accident
# 14923     EOW: Friday, January 4, 1974          Cause of Death: Heart attack
# 14924   EOW: Saturday, January 5, 1974               Cause of Death: Gunfire
# 14925   EOW: Saturday, January 5, 1974               Cause of Death: Gunfire
# 14926   EOW: Saturday, January 5, 1974                  Cause of Death: Fall
# ...                                ...                                   ...
# 22795       EOW: Sunday, June 12, 2016            Cause of Death: Accidental
# 22796       EOW: Monday, June 20, 2016       Cause of Death: Heat exhaustion
# 22797       EOW: Monday, June 27, 2016       Cause of Death: Heat exhaustion
# 22798      EOW: Tuesday, June 28, 2016  Cause of Death: Gunfire (Accidental)
# 22799        EOW: Friday, July 1, 2016   Cause of Death: Automobile accident
#
#                 cause_short        date  year  canine  \
# 14922   Automobile accident  1974-01-02  1974   False
# 14923          Heart attack  1974-01-04  1974   False
# 14924               Gunfire  1974-01-05  1974   False
# 14925               Gunfire  1974-01-05  1974   False
# 14926                  Fall  1974-01-05  1974   False
# ...                     ...         ...   ...     ...
# 22795            Accidental  2016-06-12  2016    True
# 22796       Heat exhaustion  2016-06-20  2016    True
# 22797       Heat exhaustion  2016-06-27  2016    True
# 22798  Gunfire (Accidental)  2016-06-28  2016    True
# 22799   Automobile accident  2016-07-01  2016    True
#
#                                                dept_name state
# 14922                            Lyons Police Department    NY
# 14923               Macoupin County Sheriff's Department    IL
# 14924                 Cumberland County Sheriff's Office    NC
# 14925                             Lima Police Department    OH
# 14926                      Cache County Sheriff's Office    UT
# ...                                                  ...   ...
# 22795                         Amarillo Police Department    TX
# 22796  United States Department of Homeland Security ...    US
# 22797                   Fountain County Sheriff's Office    IN
# 22798                       Long Beach Police Department    CA
# 22799                           Emmett Police Department    ID
#
# [7878 rows x 10 columns]

# %%
v_bar = px.bar(
            x = df_cause_short.index,
            y = df_cause_short.values,
            color = df_cause_short.values,
            color_continuous_scale='Aggrnyl',
            title='Number of Deaths per Cause')

v_bar.update_layout(xaxis_title='Causes',
                        coloraxis_showscale=False,
                        yaxis_title='Number of Deaths')
v_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="458ab2cf-e595-400c-be5d-8e79c1b5503b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("458ab2cf-e595-400c-be5d-8e79c1b5503b")) {                    Plotly.newPlot(                        "458ab2cf-e595-400c-be5d-8e79c1b5503b",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[3110,1272,566,543,407,276,252,224,191,148,133,110,104,88,85,76,53,41,30,29,27,22,18,17,12,10,9,6,4,4,3,3,2,2,1],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Gunfire","Automobile accident","Heart attack","Vehicular assault","Struck by vehicle","Aircraft accident","Vehicle pursuit","Motorcycle accident","Gunfire (Accidental)","Assault","Stabbed","9\u002f11 related illness","Drowned","Duty related illness","Terrorist attack","Fall","Heat exhaustion","Struck by train","Bomb","Accidental","Training accident","Exposure to toxins","Fire","Animal related","Electrocuted","Weather\u002fNatural disaster","Explosion","Bicycle accident","Boating accident","Unidentified","Exposure","Structure collapse","Poisoned","Asphyxiation","Train accident"],"xaxis":"x","y":[3110,1272,566,543,407,276,252,224,191,148,133,110,104,88,85,76,53,41,30,29,27,22,18,17,12,10,9,6,4,4,3,3,2,2,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c ...

# %% [markdown]
# # **Number Of Deaths Caused By Canines**

# %%
df_canine = df['canine'].value_counts()
df_canine
# Out:
# canine
# False    7618
# True      260
# Name: count, dtype: int64

# %%
v_bar = px.bar(
            x = df_canine.index,
            y = df_canine.values,
            color = df_canine.values,
            color_continuous_scale='Aggrnyl',
            title='Number of Deaths due to canines')

v_bar.update_layout(xaxis_title='Canine ',
                        coloraxis_showscale=False,
                        yaxis_title='Number of Deaths')
v_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="284371cf-f7fa-491c-89bb-d0934d64fd0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("284371cf-f7fa-491c-89bb-d0934d64fd0c")) {                    Plotly.newPlot(                        "284371cf-f7fa-491c-89bb-d0934d64fd0c",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[7618,260],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[false,true],"xaxis":"x","y":[7618,260],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"out ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7878 entries, 14922 to 22799
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   person       7878 non-null   object
#  1   dept         7878 non-null   object
#  2   eow          7878 non-null   object
#  3   cause        7878 non-null   object
#  4   cause_short  7878 non-null   object
#  5   date         7878 non-null   object
#  6   year         7878 non-null   int64
#  7   canine       7878 non-null   bool
#  8   dept_name    7878 non-null   object
#  9   state        7878 non-null   object
# dtypes: bool(1), int64(1), object(8)
# memory usage: 881.2+ KB

# %%
df['weekday'] = df['eow'].apply(lambda x: x.split(",")[0].split(":")[1])
df['weekday']

# %%
df
# Out:
#                                  person  \
# 14922    Chief of Police Amedeo A. Lisi
# 14923   Deputy Sheriff Donald Dean Love
# 14924     Deputy Sheriff Joe Smith, Jr.
# 14925        Patrolman William F. Brown
# 14926  Lieutenant James Raymond Merrill
# ...                                 ...
# 22795                          K9 Bruno
# 22796                          K9 Lazer
# 22797                          K9 Tyson
# 22798                          K9 Credo
# 22799                         K9 Roscoe
#
#                                                     dept  \
# 14922                        Lyons Police Department, NY
# 14923           Macoupin County Sheriff's Department, IL
# 14924             Cumberland County Sheriff's Office, NC
# 14925                         Lima Police Department, OH
# 14926                  Cache County Sheriff's Office, UT
# ...                                                  ...
# 22795                     Amarillo Police Department, TX
# 22796  United States Department of Homeland Security ...
# 22797               Fountain County Sheriff's Office, IN
# 22798                   Long Beach Police Department, CA
# 22799                       Emmett Police Department, ID
#
#                                    eow                                 cause  \
# 14922  EOW: Wednesday, January 2, 1974   Cause of Death: Automobile accident
# 14923     EOW: Friday, January 4, 1974          Cause of Death: Heart attack
# 14924   EOW: Saturday, January 5, 1974               Cause of Death: Gunfire
# 14925   EOW: Saturday, January 5, 1974               Cause of Death: Gunfire
# 14926   EOW: Saturday, January 5, 1974                  Cause of Death: Fall
# ...                                ...                                   ...
# 22795       EOW: Sunday, June 12, 2016            Cause of Death: Accidental
# 22796       EOW: Monday, June 20, 2016       Cause of Death: Heat exhaustion
# 22797       EOW: Monday, June 27, 2016       Cause of Death: Heat exhaustion
# 22798      EOW: Tuesday, June 28, 2016  Cause of Death: Gunfire (Accidental)
# 22799        EOW: Friday, July 1, 2016   Cause of Death: Automobile accident
#
#                 cause_short        date  year  canine  \
# 14922   Automobile accident  1974-01-02  1974   False
# 14923          Heart attack  1974-01-04  1974   False
# 14924               Gunfire  1974-01-05  1974   False
# 14925               Gunfire  1974-01-05  1974   False
# 14926                  Fall  1974-01-05  1974   False
# ...                     ...         ...   ...     ...
# 22795            Accidental  2016-06-12  2016    True
# 22796       Heat exhaustion  2016-06-20  2016    True
# 22797       Heat exhaustion  2016-06-27  2016    True
# 22798  Gunfire (Accidental)  2016-06-28  2016    True
# 22799   Automobile accident  2016-07-01  2016    True
#
#                                                dept_name state     weekday
# 14922                            Lyons Police Department    NY   Wednesday
# 14923               Macoupin County Sheriff's Department    IL      Friday
# 14924                 Cumberland County Sheriff's Office    NC    Saturday
# 14925                             Lima Police Department    OH    Saturday
# 14926                      Cache County Sheriff's Office    UT    Saturday
# ...                                                  ...   ...         ...
# 22795                         Amarillo Police Department    TX      Sunday
# 22796  United States Department of Homeland Security ...    US      Monday
# 22797                   Fountain County Sheriff's Office    IN      Monday
# 22798                       Long Beach Police Department    CA     Tuesday
# 22799                           Emmett Police Department    ID      Friday
#
# [7878 rows x 11 columns]

# %% [markdown]
# # **Plot Weekdays Vs. Number Of Deaths**

# %%
weekday_deaths = df['weekday'].value_counts()

# %%
v_bar = px.bar(
            x = weekday_deaths.index,
            y = weekday_deaths.values,
            color = weekday_deaths.values,
            color_continuous_scale='Aggrnyl',
            title='Number of Deaths vs. Weekdays')

v_bar.update_layout(xaxis_title='Weekdays',
                        coloraxis_showscale=False,
                        yaxis_title='Number of Deaths')
v_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2d492cbe-0b17-4ef4-83aa-61981730e803" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d492cbe-0b17-4ef4-83aa-61981730e803")) {                    Plotly.newPlot(                        "2d492cbe-0b17-4ef4-83aa-61981730e803",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[1205,1201,1152,1150,1138,1024,1008],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[" Friday"," Tuesday"," Saturday"," Wednesday"," Thursday"," Sunday"," Monday"],"xaxis":"x","y":[1205,1201,1152,1150,1138,1024,1008],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fill ...

# %% [markdown]
# # Plot Months vs. Number Of **Deaths**

# %%
df['eow']
# Out:
# 14922    EOW: Wednesday, January 2, 1974
# 14923       EOW: Friday, January 4, 1974
# 14924     EOW: Saturday, January 5, 1974
# 14925     EOW: Saturday, January 5, 1974
# 14926     EOW: Saturday, January 5, 1974
#                       ...
# 22795         EOW: Sunday, June 12, 2016
# 22796         EOW: Monday, June 20, 2016
# 22797         EOW: Monday, June 27, 2016
# 22798        EOW: Tuesday, June 28, 2016
# 22799          EOW: Friday, July 1, 2016
# Name: eow, Length: 7878, dtype: object

# %%
df['month'] = df['eow'].apply(lambda x:x.split(",")[1].split(" ")[-2])
df

# %%
month_deaths = df['month'].value_counts()

# %%
v_bar = px.bar(
            x = month_deaths.index,
            y = month_deaths.values,
            color = month_deaths.values,
            color_continuous_scale='Aggrnyl',
            title='Number of Deaths vs. Month')

v_bar.update_layout(xaxis_title='Month',
                        coloraxis_showscale=False,
                        yaxis_title='Number of Deaths')
v_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="27b20c08-8b22-4a08-8f55-631a67da1930" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27b20c08-8b22-4a08-8f55-631a67da1930")) {                    Plotly.newPlot(                        "27b20c08-8b22-4a08-8f55-631a67da1930",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[729,725,688,683,682,673,657,652,625,590,589,585],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["September","January","August","December","May","July","October","June","March","February","November","April"],"xaxis":"x","y":[729,725,688,683,682,673,657,652,625,590,589,585],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker ...

# %% [markdown]
# # Year vs. Number Of **Deaths**

# %%
year_deaths = df['year'].value_counts()

# %%
v_bar = px.bar(
            x = year_deaths.index,
            y = year_deaths.values,
            color = year_deaths.values,
            color_continuous_scale='Aggrnyl',
            title='Number of Deaths vs. Year')

v_bar.update_layout(xaxis_title='Year',
                        coloraxis_showscale=False,
                        yaxis_title='Number of Deaths')
v_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8b2f145e-eae9-46ab-80ce-e60ac5c4c9fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b2f145e-eae9-46ab-80ce-e60ac5c4c9fe")) {                    Plotly.newPlot(                        "8b2f145e-eae9-46ab-80ce-e60ac5c4c9fe",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[281,247,247,223,217,213,213,205,205,199,199,198,196,195,194,190,189,187,187,185,185,183,180,180,174,172,171,171,169,167,166,165,165,163,159,157,157,157,151,151,148,141,76],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[1974,2001,1975,1979,1978,1980,2007,1981,1976,1988,1989,1982,1977,1983,2011,1987,1984,1994,1995,1997,1986,2010,1985,1998,2005,2004,2008,2000,1992,1993,1990,2002,2014,2006,1999,2003,2012,2015,2009,1991,1996,2013,2016],"xaxis":"x","y":[281,247,247,223,217,213,213,205,205,199,199,198,196,195,194,190,189,187,187,185,185,183,180,180,174,172,171,171,169,167,166,165,165,163,159,157,157,157,151,151,148,141,76],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}] ...
